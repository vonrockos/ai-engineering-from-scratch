# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(0.02923685533723703), np.float64(1.0190194889203865))

# %%
# %timeit np.random.randn(10000)
# Out:
# 219 μs ± 1.9 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %matplotlib inline

# %%
import pandas as pd

df = pd.DataFrame({
    "model": ["Linear", "Random Forest", "Neural Net"],
    "accuracy": [0.72, 0.89, 0.94],
    "training_time": [0.1, 2.3, 45.6]
})
df
# Out:
#            model  accuracy  training_time
# 0         Linear      0.72            0.1
# 1  Random Forest      0.89            2.3
# 2     Neural Net      0.94           45.6

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.title("Inline Plot")
plt.show()

# %% [markdown]
# # Exercise 1
# Open JupyterLab, create a notebook, and use %timeit to compare list comprehension vs numpy for creating an array of 100,000 random numbers

# %%
import random

# %timeit python_list = [random.randint(1,100) for _ in range(100000)]
# Out:
# 17.8 ms ± 66 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
import numpy as np

# Generate an array of 100,000 random integers from 1 to 100
# %timeit random_numbers = np.random.randint(1, 101, size=100000)
# Out:
# 798 μs ± 3.8 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)
