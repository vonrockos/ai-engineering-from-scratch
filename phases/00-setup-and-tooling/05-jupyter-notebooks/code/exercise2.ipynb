# %% [markdown]
# # Task
# Create a notebook with both markdown and code cells that loads a CSV, displays a dataframe, and plots a chart. Then run Kernel > Restart & Run All to verify it works top to bottom

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv('sample.csv')

df
# Out:
#    jan   feb   mar   apr   may   jun   jul   aug   sep   oct   nov   dec
# 0    2     4     6     9    11    14    16    19    20    21    21    22
# 1   23    45    56    69    72    88    90    99   100   100   100   100
# 2  101   112   129   143   151   163   182   190   192   194   197   199

# %%
import matplotlib.pyplot as plt

# df.set_index('Month', inplace=True)

# Plot the chart
df.plot(kind='line', marker='o', figsize=(8, 5))

# Customize and display
#plt.title('Monthly Financial Performance')
#plt.ylabel('Amount ($)')
#plt.xlabel('Months')
#plt.grid(True)
plt.show()
