# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(0.02045435346705134), np.float64(0.9577330289645157))

# %%
# %timeit np.random.randn(10000)
# Out:
# 127 μs ± 1.27 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %matplotlib inline

# %%
# %env PATH
# Out:
# '/home/rockos/ai-engineering-from-scratch/phases/00-setup-and-tooling/05-jupyter-notebooks/exercises/.venv/bin:/home/rockos/.vscode-server/bin/e4c7e7b1d6d060162f4aa7f8225271b67ce1df75/bin/remote-cli:/home/rockos/.local/bin:/home/rockos/.juliaup/bin:/home/rockos/.cargo/bin:/run/user/1000/fnm_multishells/319_1786039559551/bin:/home/rockos/.local/share/fnm:/home/rockos/.local/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin:/usr/games:/usr/local/games:/usr/lib/wsl/lib:/mnt/c/Program Files/Common Files/Oracle/Java/javapath:/mnt/c/WINDOWS/system32:/mnt/c/WINDOWS:/mnt/c/WINDOWS/System32/Wbem:/mnt/c/WINDOWS/System32/WindowsPowerShell/v1.0/:/mnt/c/WINDOWS/System32/OpenSSH/:/mnt/c/Program Files (x86)/dotnet/:/mnt/c/Program Files/Docker/Docker/resources/bin:/mnt/c/Program Files/dotnet/:/mnt/c/Program Files/Git/cmd:/mnt/c/Users/vonro/.local/bin:/mnt/c/Users/vonro/AppData/Local/Programs/Python/Python311/Scripts/:/mnt/c/Users/vonro/AppData/Local/Programs/Python/Python311/:/mnt/c/Users/vonro/AppData/Local/Microsoft/WindowsApps:/mnt/c/Users/vonro/AppData/Local/Programs/Microsoft VS Code/bin:/mnt/c/Users/vonro/AppData/Local/Programs/Zed/bin:/mnt/c/Users/vonro/AppData/Local/Programs/cursor/resources/app/bin:/snap/bin:/mnt/c/Program Files/Notepad++'

# %%
import pandas as pd

df = pd.DataFrame({
    "model": ["Linear", "Random Forest", "Neural Net"],
    "accuracy": [0.72, 0.89, 0.94],
    "training_time": [0.1, 2.3, 45.6]
})
df
# Out:
#            model  accuracy  training_time
# 0         Linear      0.72            0.1
# 1  Random Forest      0.89            2.3
# 2     Neural Net      0.94           45.6

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.title("Inline Plot")
plt.show()

# %%
from IPython.display import Image, display
display(Image(filename="mem.jpg"))
